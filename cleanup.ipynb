# %%
import os
files = ['analyze_retrospect.py', 'extract_retrospect.py', 'extract_retrospect_v2.py', 'run_extraction.ipynb']
for f in files:
    try:
        if os.path.exists(f):
            os.remove(f)
            print(f"Deleted {f}")
        else:
            print(f"{f} not found")
    except Exception as e:
        print(f"Error deleting {f}: {e}")
# Out:
# Deleted analyze_retrospect.py
# Deleted extract_retrospect.py
# Deleted extract_retrospect_v2.py
# Deleted run_extraction.ipynb
